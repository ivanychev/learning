# %%
import numpy as np
import utils
from sklearn.metrics import roc_auc_score
from sklearn.base import BaseEstimator, ClassifierMixin
import utils
import classifiers
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from classifiers import spec_repr
from sklearn.cross_validation import StratifiedKFold
from sklearn.cross_validation import KFold
from sklearn.svm import SVC

# %%
class SVNSupermodel(BaseEstimator, ClassifierMixin):
    
    def __init__(self,
                 specs=utils.get_classifier_specs(),
                 C = [1] * len(utils.get_classifier_specs()), 
                 superclassifier = LogisticRegression()):
        assert len(specs) == len(C), "Specs and regularization constants arrays lengths don't match"
        self.C = C
        self.specs = specs
        self.clfs = classifiers.get(self.specs, self.C)
        self.margins = None
        self.superclassifier = superclassifier
        
    def fit(self, X, y=None, verbose=True):
        """
        Fitting each SVM, calculating margins then fitting superclassifier
        """
        for clf, spec in zip(self.clfs, self.specs):
            clf.fit(X, y)
            if verbose:
                print("Fitted %s" % spec_repr(spec))
        self.margins = utils.get_margins(self.clfs, X)
        if verbose:
            print("Margins calculated")
        self.superclassifier.fit(self.margins, y)
        
    def predict(self, X, y=None):
        margins = utils.get_margins(self.clfs, X)
        return self.superclassifier.predict(margins)
    
    def predict_proba(self, X, y=None):
        margins = utils.get_margins(self.clfs, X)
        return self.superclassifier.predict_proba(margins)
    
    def score(self, X, y=None):
        return roc_auc_score(y, self.predict_proba(X))
    
    def score_stats(self, X, y=None, verbose=True):
        """
        Calculating ROC for each SVM and for supermodel
        """
        scores = []
        for clf, spec in zip(self.clfs, self.specs):
            prediction = clf.decision_function(X)
            scores.append(roc_auc_score(y, prediction))
            if verbose:
                print("%s ROC: %f" % (spec_repr(spec), scores[-1]))
        super_score = roc_auc_score(y, self.predict_proba(X)[:, 1])
        if verbose:
            print("Superclassifier ROC: %f" % super_score)
        return scores, super_score
    
    def fit_score_stats(self, X_train, X_test, y_train, y_test, verbose=True):
        """
        Fitting and scoring combined
        """
        self.fit(X_train, y_train, verbose=verbose)
        if verbose:
            print("Fitted")
        return self.score_stats(X_test, y_test, verbose=verbose)
    
    def cross_val_stats(self, X, y, cv_type="stratified", n_folds=5):
        """
        The function includes data splitting and scoring
        """
        if cv_type == "stratified":
            cv = StratifiedKFold(y, n_folds=n_folds)
        elif cv_type == "simple":
            cv = KFold(np.size(y), n_folds=n_folds)
        else:
            raise ValueError("Invalid cv_type")
        scores = []
        for train, test in cv:
            clfs_scores, super_score = \
                self.fit_score_stats(X[train], X[test], y[train], y[test], verbose=True)
            scores.append((clfs_scores, super_score))
        return scores

# %%
cls = SVNSupermodel()

# %%
for name in utils.datasets:
    X, y, _ = utils.get_dataset(name)
    print("TESTING %s" % name.upper())
    x = cls.cross_val_stats(X, y, cv_type="stratified", n_folds=5)
# Out:
# TESTING HOUSING
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Fitted
# Kernel type: linear ROC: 0.930390
# Kernel type: poly, degree = 2 ROC: 0.733506
# Kernel type: poly, degree = 3 ROC: 0.938182
# Kernel type: poly, degree = 4 ROC: 0.841558
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.943377
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.942338
# Kernel type: rbf, gamma = 0.000100 ROC: 0.925714
# Kernel type: rbf, gamma = 0.001000 ROC: 0.925714
# Kernel type: rbf, gamma = 0.001000 ROC: 0.925714
# Kernel type: rbf, gamma = 0.010000 ROC: 0.934026
# Kernel type: rbf, gamma = 0.100000 ROC: 0.940260
# Kernel type: rbf, gamma = 1.000000 ROC: 0.871688
# Superclassifier ROC: 0.930390
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Fitted
# Kernel type: linear ROC: 0.974026
# Kernel type: poly, degree = 2 ROC: 0.735065
# Kernel type: poly, degree = 3 ROC: 0.960000
# Kernel type: poly, degree = 4 ROC: 0.884675
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.965195
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.966234
# Kernel type: rbf, gamma = 0.000100 ROC: 0.963117
# Kernel type: rbf, gamma = 0.001000 ROC: 0.963636
# Kernel type: rbf, gamma = 0.001000 ROC: 0.963636
# Kernel type: rbf, gamma = 0.010000 ROC: 0.961558
# Kernel type: rbf, gamma = 0.100000 ROC: 0.898701
# Kernel type: rbf, gamma = 1.000000 ROC: 0.816104
# Superclassifier ROC: 0.880000
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Fitted
# Kernel type: linear ROC: 0.955789
# Kernel type: poly, degree = 2 ROC: 0.818947
# Kernel type: poly, degree = 3 ROC: 0.917368
# Kernel type: poly, degree = 4 ROC: 0.890000
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.938421
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.928421
# Kernel type: rbf, gamma = 0.000100 ROC: 0.912105
# Kernel type: rbf, gamma = 0.001000 ROC: 0.907895
# Kernel type: rbf, gamma = 0.001000 ROC: 0.907895
# Kernel type: rbf, gamma = 0.010000 ROC: 0.942105
# Kernel type: rbf, gamma = 0.100000 ROC: 0.943158
# Kernel type: rbf, gamma = 1.000000 ROC: 0.823684
# Superclassifier ROC: 0.900526
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Fitted
# Kernel type: linear ROC: 0.933684
# Kernel type: poly, degree = 2 ROC: 0.733158
# Kernel type: poly, degree = 3 ROC: 0.955789
# Kernel type: poly, degree = 4 ROC: 0.739474
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.971579
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.956316
# Kernel type: rbf, gamma = 0.000100 ROC: 0.982105
# Kernel type: rbf, gamma = 0.001000 ROC: 0.982105
# Kernel type: rbf, gamma = 0.001000 ROC: 0.982105
# Kernel type: rbf, gamma = 0.010000 ROC: 0.978947
# Kernel type: rbf, gamma = 0.100000 ROC: 0.964211
# Kernel type: rbf, gamma = 1.000000 ROC: 0.842105
# Superclassifier ROC: 0.935263
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Fitted
# Kernel type: linear ROC: 0.825110
# Kernel type: poly, degree = 2 ROC: 0.734649
# Kernel type: poly, degree = 3 ROC: 0.828947
# Kernel type: poly, degree = 4 ROC: 0.705592
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.883224
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.883224
# Kernel type: rbf, gamma = 0.000100 ROC: 0.865680
# Kernel type: rbf, gamma = 0.001000 ROC: 0.865680
# Kernel type: rbf, gamma = 0.001000 ROC: 0.865680
# Kernel type: rbf, gamma = 0.010000 ROC: 0.862939
# Kernel type: rbf, gamma = 0.100000 ROC: 0.915022
# Kernel type: rbf, gamma = 1.000000 ROC: 0.812500
# Superclassifier ROC: 0.854715
# TESTING SPAMBASE
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Fitted
# Kernel type: linear ROC: 0.968633
# Kernel type: poly, degree = 2 ROC: 0.938848
# Kernel type: poly, degree = 3 ROC: 0.956602
# Kernel type: poly, degree = 4 ROC: 0.924556
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.976088
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.975115
# Kernel type: rbf, gamma = 0.000100 ROC: 0.946417
# Kernel type: rbf, gamma = 0.001000 ROC: 0.957298
# Kernel type: rbf, gamma = 0.001000 ROC: 0.957298
# Kernel type: rbf, gamma = 0.010000 ROC: 0.966964
# Kernel type: rbf, gamma = 0.100000 ROC: 0.955861
# Kernel type: rbf, gamma = 1.000000 ROC: 0.913450
# Superclassifier ROC: 0.953175
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Fitted
# Kernel type: linear ROC: 0.979857
# Kernel type: poly, degree = 2 ROC: 0.948809
# Kernel type: poly, degree = 3 ROC: 0.953109
# Kernel type: poly, degree = 4 ROC: 0.929318
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.981457
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.981185
# Kernel type: rbf, gamma = 0.000100 ROC: 0.955804
# Kernel type: rbf, gamma = 0.001000 ROC: 0.968774
# Kernel type: rbf, gamma = 0.001000 ROC: 0.968774
# Kernel type: rbf, gamma = 0.010000 ROC: 0.976219
# Kernel type: rbf, gamma = 0.100000 ROC: 0.953163
# Kernel type: rbf, gamma = 1.000000 ROC: 0.907193
# Superclassifier ROC: 0.966256
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Fitted
# Kernel type: linear ROC: 0.964992
# Kernel type: poly, degree = 2 ROC: 0.944059
# Kernel type: poly, degree = 3 ROC: 0.953336
# Kernel type: poly, degree = 4 ROC: 0.933430
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.981338
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.980879
# Kernel type: rbf, gamma = 0.000100 ROC: 0.955528
# Kernel type: rbf, gamma = 0.001000 ROC: 0.967125
# Kernel type: rbf, gamma = 0.001000 ROC: 0.967125
# Kernel type: rbf, gamma = 0.010000 ROC: 0.977448
# Kernel type: rbf, gamma = 0.100000 ROC: 0.971257
# Kernel type: rbf, gamma = 1.000000 ROC: 0.936447
# Superclassifier ROC: 0.961595
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Fitted
# Kernel type: linear ROC: 0.983535
# Kernel type: poly, degree = 2 ROC: 0.957076
# Kernel type: poly, degree = 3 ROC: 0.969489
# Kernel type: poly, degree = 4 ROC: 0.948084
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.993647
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.992556
# Kernel type: rbf, gamma = 0.000100 ROC: 0.971944
# Kernel type: rbf, gamma = 0.001000 ROC: 0.979661
# Kernel type: rbf, gamma = 0.001000 ROC: 0.979661
# Kernel type: rbf, gamma = 0.010000 ROC: 0.990463
# Kernel type: rbf, gamma = 0.100000 ROC: 0.977777
# Kernel type: rbf, gamma = 1.000000 ROC: 0.935668
# Superclassifier ROC: 0.958757
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Fitted
# Kernel type: linear ROC: 0.882941
# Kernel type: poly, degree = 2 ROC: 0.889275
# Kernel type: poly, degree = 3 ROC: 0.845021
# Kernel type: poly, degree = 4 ROC: 0.852684
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.908795
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.904788
# Kernel type: rbf, gamma = 0.000100 ROC: 0.849286
# Kernel type: rbf, gamma = 0.001000 ROC: 0.875596
# Kernel type: rbf, gamma = 0.001000 ROC: 0.875596
# Kernel type: rbf, gamma = 0.010000 ROC: 0.896987
# Kernel type: rbf, gamma = 0.100000 ROC: 0.865432
# Kernel type: rbf, gamma = 1.000000 ROC: 0.775326
# Superclassifier ROC: 0.861497
# TESTING WINE
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Fitted
# Kernel type: linear ROC: 0.732002
# Kernel type: poly, degree = 2 ROC: 0.690203
# Kernel type: poly, degree = 3 ROC: 0.769583
# Kernel type: poly, degree = 4 ROC: 0.695403
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.785818
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.781601
# Kernel type: rbf, gamma = 0.000100 ROC: 0.737735
# Kernel type: rbf, gamma = 0.001000 ROC: 0.735724
# Kernel type: rbf, gamma = 0.001000 ROC: 0.735724
# Kernel type: rbf, gamma = 0.010000 ROC: 0.762434
# Kernel type: rbf, gamma = 0.100000 ROC: 0.772917
# Kernel type: rbf, gamma = 1.000000 ROC: 0.728217
# Superclassifier ROC: 0.669385
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Fitted
# Kernel type: linear ROC: 0.793969
# Kernel type: poly, degree = 2 ROC: 0.670283
# Kernel type: poly, degree = 3 ROC: 0.767315
# Kernel type: poly, degree = 4 ROC: 0.664134
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.808769
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.808465
# Kernel type: rbf, gamma = 0.000100 ROC: 0.763635
# Kernel type: rbf, gamma = 0.001000 ROC: 0.775620
# Kernel type: rbf, gamma = 0.001000 ROC: 0.775620
# Kernel type: rbf, gamma = 0.010000 ROC: 0.808974
# Kernel type: rbf, gamma = 0.100000 ROC: 0.783728
# Kernel type: rbf, gamma = 1.000000 ROC: 0.712952
# Superclassifier ROC: 0.591038
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Fitted
# Kernel type: linear ROC: 0.820225
# Kernel type: poly, degree = 2 ROC: 0.650653
# Kernel type: poly, degree = 3 ROC: 0.804630
# Kernel type: poly, degree = 4 ROC: 0.743795
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.827992
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.830007
# Kernel type: rbf, gamma = 0.000100 ROC: 0.818284
# Kernel type: rbf, gamma = 0.001000 ROC: 0.820173
# Kernel type: rbf, gamma = 0.001000 ROC: 0.820173
# Kernel type: rbf, gamma = 0.010000 ROC: 0.825724
# Kernel type: rbf, gamma = 0.100000 ROC: 0.825584
# Kernel type: rbf, gamma = 1.000000 ROC: 0.791509
# Superclassifier ROC: 0.701009
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Fitted
# Kernel type: linear ROC: 0.814333
# Kernel type: poly, degree = 2 ROC: 0.695965
# Kernel type: poly, degree = 3 ROC: 0.779973
# Kernel type: poly, degree = 4 ROC: 0.709031
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.829905
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.826655
# Kernel type: rbf, gamma = 0.000100 ROC: 0.785639
# Kernel type: rbf, gamma = 0.001000 ROC: 0.799502
# Kernel type: rbf, gamma = 0.001000 ROC: 0.799502
# Kernel type: rbf, gamma = 0.010000 ROC: 0.824098
# Kernel type: rbf, gamma = 0.100000 ROC: 0.813224
# Kernel type: rbf, gamma = 1.000000 ROC: 0.788777
# Superclassifier ROC: 0.712895
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Fitted
# Kernel type: linear ROC: 0.814891
# Kernel type: poly, degree = 2 ROC: 0.717592
# Kernel type: poly, degree = 3 ROC: 0.789789
# Kernel type: poly, degree = 4 ROC: 0.755447
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.860304
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.851354
# Kernel type: rbf, gamma = 0.000100 ROC: 0.813767
# Kernel type: rbf, gamma = 0.001000 ROC: 0.814521
# Kernel type: rbf, gamma = 0.001000 ROC: 0.814521
# Kernel type: rbf, gamma = 0.010000 ROC: 0.843323
# Kernel type: rbf, gamma = 0.100000 ROC: 0.865535
# Kernel type: rbf, gamma = 1.000000 ROC: 0.809842
# Superclassifier ROC: 0.675064
# TESTING HEART
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Fitted
# Kernel type: linear ROC: 0.890625
# Kernel type: poly, degree = 2 ROC: 0.674107
# Kernel type: poly, degree = 3 ROC: 0.904018
# Kernel type: poly, degree = 4 ROC: 0.762277
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.897321
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.899554
# Kernel type: rbf, gamma = 0.000100 ROC: 0.885045
# Kernel type: rbf, gamma = 0.001000 ROC: 0.888393
# Kernel type: rbf, gamma = 0.001000 ROC: 0.888393
# Kernel type: rbf, gamma = 0.010000 ROC: 0.898438
# Kernel type: rbf, gamma = 0.100000 ROC: 0.879464
# Kernel type: rbf, gamma = 1.000000 ROC: 0.850446
# Superclassifier ROC: 0.890625
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Fitted
# Kernel type: linear ROC: 0.948661
# Kernel type: poly, degree = 2 ROC: 0.564732
# Kernel type: poly, degree = 3 ROC: 0.960938
# Kernel type: poly, degree = 4 ROC: 0.727679
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.960938
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.962054
# Kernel type: rbf, gamma = 0.000100 ROC: 0.952009
# Kernel type: rbf, gamma = 0.001000 ROC: 0.953125
# Kernel type: rbf, gamma = 0.001000 ROC: 0.953125
# Kernel type: rbf, gamma = 0.010000 ROC: 0.959821
# Kernel type: rbf, gamma = 0.100000 ROC: 0.954241
# Kernel type: rbf, gamma = 1.000000 ROC: 0.719866
# Superclassifier ROC: 0.936384
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Fitted
# Kernel type: linear ROC: 0.896991
# Kernel type: poly, degree = 2 ROC: 0.761574
# Kernel type: poly, degree = 3 ROC: 0.876157
# Kernel type: poly, degree = 4 ROC: 0.813657
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.875000
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.865741
# Kernel type: rbf, gamma = 0.000100 ROC: 0.887731
# Kernel type: rbf, gamma = 0.001000 ROC: 0.888889
# Kernel type: rbf, gamma = 0.001000 ROC: 0.888889
# Kernel type: rbf, gamma = 0.010000 ROC: 0.883102
# Kernel type: rbf, gamma = 0.100000 ROC: 0.869213
# Kernel type: rbf, gamma = 1.000000 ROC: 0.739583
# Superclassifier ROC: 0.851852
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Fitted
# Kernel type: linear ROC: 0.894676
# Kernel type: poly, degree = 2 ROC: 0.739583
# Kernel type: poly, degree = 3 ROC: 0.922454
# Kernel type: poly, degree = 4 ROC: 0.730324
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.924769
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.917824
# Kernel type: rbf, gamma = 0.000100 ROC: 0.930556
# Kernel type: rbf, gamma = 0.001000 ROC: 0.928241
# Kernel type: rbf, gamma = 0.001000 ROC: 0.928241
# Kernel type: rbf, gamma = 0.010000 ROC: 0.921296
# Kernel type: rbf, gamma = 0.100000 ROC: 0.920139
# Kernel type: rbf, gamma = 1.000000 ROC: 0.868056
# Superclassifier ROC: 0.888889
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Fitted
# Kernel type: linear ROC: 0.896991
# Kernel type: poly, degree = 2 ROC: 0.662037
# Kernel type: poly, degree = 3 ROC: 0.883102
# Kernel type: poly, degree = 4 ROC: 0.755787
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.883102
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.878472
# Kernel type: rbf, gamma = 0.000100 ROC: 0.879630
# Kernel type: rbf, gamma = 0.001000 ROC: 0.877315
# Kernel type: rbf, gamma = 0.001000 ROC: 0.877315
# Kernel type: rbf, gamma = 0.010000 ROC: 0.890046
# Kernel type: rbf, gamma = 0.100000 ROC: 0.870370
# Kernel type: rbf, gamma = 1.000000 ROC: 0.793981
# Superclassifier ROC: 0.868056
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# TESTING GERMAN
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Fitted
# Kernel type: linear ROC: 0.765119
# Kernel type: poly, degree = 2 ROC: 0.565357
# Kernel type: poly, degree = 3 ROC: 0.764048
# Kernel type: poly, degree = 4 ROC: 0.686667
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.780714
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.785000
# Kernel type: rbf, gamma = 0.000100 ROC: 0.769048
# Kernel type: rbf, gamma = 0.001000 ROC: 0.769286
# Kernel type: rbf, gamma = 0.001000 ROC: 0.769286
# Kernel type: rbf, gamma = 0.010000 ROC: 0.772143
# Kernel type: rbf, gamma = 0.100000 ROC: 0.756310
# Kernel type: rbf, gamma = 1.000000 ROC: 0.588333
# Superclassifier ROC: 0.742976
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Fitted
# Kernel type: linear ROC: 0.776190
# Kernel type: poly, degree = 2 ROC: 0.665000
# Kernel type: poly, degree = 3 ROC: 0.772976
# Kernel type: poly, degree = 4 ROC: 0.728929
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.781905
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.778333
# Kernel type: rbf, gamma = 0.000100 ROC: 0.772500
# Kernel type: rbf, gamma = 0.001000 ROC: 0.772976
# Kernel type: rbf, gamma = 0.001000 ROC: 0.772976
# Kernel type: rbf, gamma = 0.010000 ROC: 0.781786
# Kernel type: rbf, gamma = 0.100000 ROC: 0.767500
# Kernel type: rbf, gamma = 1.000000 ROC: 0.714286
# Superclassifier ROC: 0.766190
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Fitted
# Kernel type: linear ROC: 0.826310
# Kernel type: poly, degree = 2 ROC: 0.606429
# Kernel type: poly, degree = 3 ROC: 0.784048
# Kernel type: poly, degree = 4 ROC: 0.700357
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.841310
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.839524
# Kernel type: rbf, gamma = 0.000100 ROC: 0.825595
# Kernel type: rbf, gamma = 0.001000 ROC: 0.825238
# Kernel type: rbf, gamma = 0.001000 ROC: 0.825238
# Kernel type: rbf, gamma = 0.010000 ROC: 0.839286
# Kernel type: rbf, gamma = 0.100000 ROC: 0.781905
# Kernel type: rbf, gamma = 1.000000 ROC: 0.685000
# Superclassifier ROC: 0.762500
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Fitted
# Kernel type: linear ROC: 0.761548
# Kernel type: poly, degree = 2 ROC: 0.725476
# Kernel type: poly, degree = 3 ROC: 0.795595
# Kernel type: poly, degree = 4 ROC: 0.793333
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.764048
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.753810
# Kernel type: rbf, gamma = 0.000100 ROC: 0.757500
# Kernel type: rbf, gamma = 0.001000 ROC: 0.759048
# Kernel type: rbf, gamma = 0.001000 ROC: 0.759048
# Kernel type: rbf, gamma = 0.010000 ROC: 0.776071
# Kernel type: rbf, gamma = 0.100000 ROC: 0.756786
# Kernel type: rbf, gamma = 1.000000 ROC: 0.655298
# Superclassifier ROC: 0.762024
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Fitted
# Kernel type: linear ROC: 0.819762
# Kernel type: poly, degree = 2 ROC: 0.688333
# Kernel type: poly, degree = 3 ROC: 0.746429
# Kernel type: poly, degree = 4 ROC: 0.663333
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.822976
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.822262
# Kernel type: rbf, gamma = 0.000100 ROC: 0.830476
# Kernel type: rbf, gamma = 0.001000 ROC: 0.830357
# Kernel type: rbf, gamma = 0.001000 ROC: 0.830357
# Kernel type: rbf, gamma = 0.010000 ROC: 0.826429
# Kernel type: rbf, gamma = 0.100000 ROC: 0.759524
# Kernel type: rbf, gamma = 1.000000 ROC: 0.649702
# Superclassifier ROC: 0.724167
