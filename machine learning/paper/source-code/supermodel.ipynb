# %%
import numpy as np
import utils
from sklearn.metrics import roc_auc_score
from sklearn.base import BaseEstimator, ClassifierMixin
import utils
import classifiers
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from classifiers import spec_repr
from sklearn.cross_validation import StratifiedKFold
from sklearn.cross_validation import KFold
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler

# %%
class SVNSupermodel(BaseEstimator, ClassifierMixin):
    
    def __init__(self,
                 specs=utils.get_classifier_specs(),
                 C = [100] * len(utils.get_classifier_specs()), 
                 superclassifier = LogisticRegression()):
        assert len(specs) == len(C), "Specs and regularization constants arrays lengths don't match"
        self.C = C
        self.specs = specs
        self.clfs = classifiers.get(self.specs, self.C)
        self.margins = None
        self.superclassifier = superclassifier
        self.margin_mean_abs = None
        
    def scale_train_margins(self, margins):
        abs_margins = np.abs(margins)
        margin_mean_abs = np.mean(abs_margins, axis=0)
        self.margin_mean_abs = margin_mean_abs
        return margins / margin_mean_abs
    
    def scale_test_margins(self, margins):
        return margins / self.margin_mean_abs
#     def scale_train_margins(self, margins):
#         self.scaler = StandardScaler()
#         return self.scaler.fit_transform(margins)
    
#     def scale_test_margins(self, margins):
#         return self.scaler.transform(margins)
        
    def fit(self, X, y=None, verbose=True):
        """
        Fitting each SVM, calculating margins then fitting superclassifier
        """
        for clf, spec in zip(self.clfs, self.specs):
            clf.fit(X, y)
            if verbose:
                print("Fitted %s" % spec_repr(spec))
        self.margins = self.scale_train_margins(utils.get_margins(self.clfs, X))
        if verbose:
            print("Margins calculated")
        self.superclassifier.fit(self.margins, y)
        print("Logregr coefs", self.superclassifier.coef_)
#         print(cls.clfs[6].predict(X))
        
    def predict(self, X, y=None):
        margins = utils.get_margins(self.clfs, X)
        margins = self.scale_test_margins(margins)
        return self.superclassifier.predict(margins)
    
    def predict_proba(self, X, y=None):
        margins = utils.get_margins(self.clfs, X)
        margins = self.scale_test_margins(margins)
        print("margin mins", np.min(margins, axis=0))
        print("margin maxs", np.max(margins, axis=0))
        print("margin means", np.mean(margins, axis=0))
        print("margin abs means", np.mean(np.abs(margins), axis=0))
        print("margin stds", np.std(margins, axis=0))
        return self.superclassifier.predict_proba(margins)
    
    def score(self, X, y=None):
        return roc_auc_score(y, self.predict_proba(X))
    
    def score_stats(self, X, y=None, verbose=True):
        """
        Calculating ROC for each SVM and for supermodel
        """
        scores = []
        acc_scores = []
        for clf, spec in zip(self.clfs, self.specs):
            prediction = clf.decision_function(X)
            scores.append(roc_auc_score(y, prediction))
            acc_scores.append(accuracy_score(y, clf.predict(X)))
            if verbose:
                print("%s ROC: %f" % (spec_repr(spec), scores[-1]))
#                 print("%s Acc: %f" % (spec_repr(spec), acc_scores[-1]))
        super_score = roc_auc_score(y, self.predict_proba(X)[:, 1])
        if verbose:
            print("Superclassifier ROC: %f" % super_score)
        return scores, super_score
    
    def fit_score_stats(self, X_train, X_test, y_train, y_test, verbose=True):
        """
        Fitting and scoring combined
        """
        self.fit(X_train, y_train, verbose=verbose)
        if verbose:
            print("Fitted")
        return self.score_stats(X_test, y_test, verbose=verbose)
    
    def cross_val_stats(self, X, y, cv_type="stratified", n_folds=5):
        """
        The function includes data splitting and scoring
        """
        if cv_type == "stratified":
            cv = StratifiedKFold(y, n_folds=n_folds)
        elif cv_type == "simple":
            cv = KFold(np.size(y), n_folds=n_folds)
        else:
            raise ValueError("Invalid cv_type")
        scores = []
        for train, test in cv:
            clfs_scores, super_score = \
                self.fit_score_stats(X[train], X[test], y[train], y[test], verbose=True)
            scores.append((clfs_scores, super_score))
        return scores

# %%
cls = SVNSupermodel()

# %% [markdown]
# ## Logregr coefs here

# %%
for name in ["german"]:
    X, y, _ = utils.get_dataset(name)
    print(np.sum(y==1))
    print(np.sum(y==0))
    print("TESTING %s" % name.upper())
    x = cls.cross_val_stats(X, y, cv_type="stratified", n_folds=5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 300
# 700
# TESTING GERMAN
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/svm/base.py:224: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Logregr coefs [[ 0.00788161  0.22025555  0.86253403  1.02886066  0.7957329   0.60019978
#   -0.01286558  0.00565579  0.29010771  1.6699392   1.81754941]]
# Fitted
# Kernel type: linear ROC: 0.758929
# Kernel type: poly, degree = 2 ROC: 0.605595
# Kernel type: poly, degree = 3 ROC: 0.698690
# Kernel type: poly, degree = 4 ROC: 0.642024
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.685119
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.686429
# Kernel type: rbf, gamma = 0.000100 ROC: 0.766905
# Kernel type: rbf, gamma = 0.001000 ROC: 0.764524
# Kernel type: rbf, gamma = 0.010000 ROC: 0.733810
# Kernel type: rbf, gamma = 0.100000 ROC: 0.710119
# Kernel type: rbf, gamma = 1.000000 ROC: 0.595298
# margin mins [-3.41320206 -7.79765075 -6.40548159 -5.27048301 -3.05615824 -3.31431673
#  -3.04710948 -2.74484453 -3.4026993  -1.82270575 -1.00704762]
# margin maxs [ 1.6569196   4.44549208  2.43626568  2.51565831  2.70195349  3.12400346
#   1.58859672  1.973183    2.96606409  2.12782387  0.83554704]
# margin means [-0.74304455 -0.64788372 -0.54170838 -0.45823147 -0.43368805 -0.4463721
#  -0.81488558 -0.75044409 -0.57011748 -0.37841337 -0.38845153]
# margin abs means [ 0.98034238  1.06937724  0.91207797  0.7614902   0.80169786  0.81511268
#   0.97331935  0.95982892  0.89246904  0.61906921  0.39883846]
# margin stds [ 0.99595228  1.55225433  1.14476983  0.85928071  0.93988965  0.96638705
#   0.89457139  0.91674088  0.98376185  0.66331929  0.11812345]
# Superclassifier ROC: 0.709405
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Logregr coefs [[ 0.01040784  0.22064467  0.86168462  1.10731916  0.82755233  0.64970572
#    0.00551602  0.02647483  0.2598541   1.60751754  1.72916861]]
# Fitted
# Kernel type: linear ROC: 0.775119
# Kernel type: poly, degree = 2 ROC: 0.616548
# Kernel type: poly, degree = 3 ROC: 0.725357
# Kernel type: poly, degree = 4 ROC: 0.636905
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.775000
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.760714
# Kernel type: rbf, gamma = 0.000100 ROC: 0.778095
# Kernel type: rbf, gamma = 0.001000 ROC: 0.776548
# Kernel type: rbf, gamma = 0.010000 ROC: 0.759286
# Kernel type: rbf, gamma = 0.100000 ROC: 0.748333
# Kernel type: rbf, gamma = 1.000000 ROC: 0.713869
# margin mins [ -3.85941826 -12.67028134  -5.3537279   -2.92786878  -3.22108844
#   -3.41203332  -3.35030712  -3.35458395  -3.05551414  -2.37939363
#   -0.91164997]
# margin maxs [ 1.79972513  7.3962131   5.28826862  2.1831328   1.94106133  2.39915773
#   1.48167758  1.79108322  2.0347633   1.91095513  0.83556175]
# margin means [-0.80043376 -0.71264649 -0.68794475 -0.64506569 -0.67723606 -0.65885424
#  -0.88353568 -0.8253243  -0.72272149 -0.58144173 -0.40423183]
# margin abs means [ 1.05813813  1.31434196  1.16917983  0.87070715  1.02477066  1.03218169
#   1.05523617  1.04275176  1.0388416   0.76696451  0.41259539]
# margin stds [ 1.00289593  1.95983152  1.31611915  0.82118744  1.04264717  1.05738211
#   0.8995939   0.95380388  1.02766727  0.70083496  0.11442101]
# Superclassifier ROC: 0.757976
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Logregr coefs [[ 0.03595378  0.19738621  0.87551306  1.04092775  0.77319507  0.61791935
#   -0.02497533  0.0228337   0.2483302   1.66731368  1.823353  ]]
# Fitted
# Kernel type: linear ROC: 0.826310
# Kernel type: poly, degree = 2 ROC: 0.637976
# Kernel type: poly, degree = 3 ROC: 0.680000
# Kernel type: poly, degree = 4 ROC: 0.667500
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.707619
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.689524
# Kernel type: rbf, gamma = 0.000100 ROC: 0.828690
# Kernel type: rbf, gamma = 0.001000 ROC: 0.834405
# Kernel type: rbf, gamma = 0.010000 ROC: 0.751310
# Kernel type: rbf, gamma = 0.100000 ROC: 0.722024
# Kernel type: rbf, gamma = 1.000000 ROC: 0.677143
# margin mins [-2.60449929 -6.91468603 -4.8110785  -4.56368977 -2.93829221 -2.99103595
#  -2.38093347 -2.44326874 -3.36776489 -1.83875775 -0.97951573]
# margin maxs [ 1.95586916  4.92248774  3.65280649  3.23701541  4.02061589  3.81688003
#   1.76369188  2.10263776  3.75629593  1.72235659  0.16737683]
# margin means [-0.73621398 -0.66724876 -0.48878375 -0.48391002 -0.49297633 -0.53669408
#  -0.81835765 -0.75017296 -0.58999446 -0.443084   -0.4063936 ]
# margin abs means [ 0.97127445  1.20570664  0.9233452   0.76754388  0.86830068  0.92466079
#   0.98378899  0.97984439  0.93867968  0.65342954  0.40806736]
# margin stds [ 0.90052107  1.55001488  1.1173542   0.86542443  0.9913133   1.023412
#   0.81642649  0.88131636  1.00968654  0.66314241  0.07849939]
# Superclassifier ROC: 0.725000
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Logregr coefs [[  7.30927694e-04   1.44322313e-01   8.29699271e-01   1.01986545e+00
#     7.49717939e-01   5.76830375e-01   2.88472424e-04   8.35607648e-03
#     2.01287708e-01   1.72079973e+00   1.89738909e+00]]
# Fitted
# Kernel type: linear ROC: 0.762500
# Kernel type: poly, degree = 2 ROC: 0.644048
# Kernel type: poly, degree = 3 ROC: 0.677738
# Kernel type: poly, degree = 4 ROC: 0.701905
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.733452
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.723452
# Kernel type: rbf, gamma = 0.000100 ROC: 0.765595
# Kernel type: rbf, gamma = 0.001000 ROC: 0.777262
# Kernel type: rbf, gamma = 0.010000 ROC: 0.739881
# Kernel type: rbf, gamma = 0.100000 ROC: 0.760714
# Kernel type: rbf, gamma = 1.000000 ROC: 0.648750
# margin mins [-2.71888035 -7.55739554 -3.83065223 -3.18834072 -3.01373771 -3.10266296
#  -2.73332452 -2.59368448 -3.59076772 -2.70784929 -0.75438052]
# margin maxs [ 1.48818323  4.50227885  2.75602271  2.57148753  1.93246904  2.0919706
#   1.25553708  1.3618003   2.33951177  1.4406148   0.16706905]
# margin means [-0.74601066 -0.3895054  -0.55693997 -0.34972341 -0.46193944 -0.47645621
#  -0.78640502 -0.74578699 -0.50337144 -0.42458228 -0.40012068]
# margin abs means [ 0.97584804  1.11141838  0.9850952   0.76550737  0.84835995  0.87363172
#   0.96248922  0.9514658   0.95742307  0.62692281  0.40179137]
# margin stds [ 0.93923651  1.51342892  1.1273412   0.90172749  0.94763802  0.9888318
#   0.8844172   0.88352782  1.06910624  0.65283496  0.06849319]
# Superclassifier ROC: 0.750000
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Logregr coefs [[ 0.03147173  0.12891707  0.87643677  1.00848642  0.82311239  0.65254148
#    0.00754844  0.01286249  0.23832431  1.64576555  1.79029565]]
# Fitted
# Kernel type: linear ROC: 0.819881
# Kernel type: poly, degree = 2 ROC: 0.651429
# Kernel type: poly, degree = 3 ROC: 0.657143
# Kernel type: poly, degree = 4 ROC: 0.679167
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.719167
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.731071
# Kernel type: rbf, gamma = 0.000100 ROC: 0.828810
# Kernel type: rbf, gamma = 0.001000 ROC: 0.817500
# Kernel type: rbf, gamma = 0.010000 ROC: 0.765238
# Kernel type: rbf, gamma = 0.100000 ROC: 0.697619
# Kernel type: rbf, gamma = 1.000000 ROC: 0.651667
# margin mins [ -3.10172297 -12.86654058  -7.03143749  -3.35909035  -2.51773248
#   -2.3696147   -2.92290059  -2.73254337  -2.63469914  -2.51068947
#   -0.68226242]
# margin maxs [ 2.22832386  7.3417312   3.70920761  5.8976982   1.9174321   2.37439424
#   1.87743088  1.94532691  2.71989144  1.2753996  -0.18019819]
# margin means [-0.70853563 -0.72317087 -0.43532546 -0.42113391 -0.50258756 -0.50283619
#  -0.78987578 -0.69784759 -0.50426792 -0.45214724 -0.40324343]
# margin abs means [ 1.02747289  1.48912097  0.98367234  0.87265031  0.83901711  0.85281891
#   1.02137126  1.01009987  0.88450102  0.63294146  0.40324343]
# margin stds [ 1.00926092  2.429093    1.26671855  1.05975379  0.88042772  0.90471037
#   0.92382827  0.97090695  0.95851066  0.66953021  0.04568989]
# Superclassifier ROC: 0.726905

# %%
for name in utils.datasets:
    cls = SVNSupermodel()
    X, y, _ = utils.get_dataset(name)
    print("TESTING %s" % name.upper())
    x = cls.cross_val_stats(X, y, cv_type="stratified", n_folds=5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# TESTING GERMAN
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Logregr coefs [[-0.0111976   0.13809596  0.58744742  0.70042898  0.34585317  0.27016642
#   -0.19996763 -0.06135211 -0.05824642  1.76757965  2.88933883]]
# Fitted
# Kernel type: linear ROC: 0.766429
# Kernel type: poly, degree = 2 ROC: 0.597857
# Kernel type: poly, degree = 3 ROC: 0.718095
# Kernel type: poly, degree = 4 ROC: 0.658452
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.765595
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.762857
# Kernel type: rbf, gamma = 0.000100 ROC: 0.767381
# Kernel type: rbf, gamma = 0.001000 ROC: 0.768690
# Kernel type: rbf, gamma = 0.010000 ROC: 0.785119
# Kernel type: rbf, gamma = 0.100000 ROC: 0.715476
# Kernel type: rbf, gamma = 1.000000 ROC: 0.595298
# margin mins [-3.35181859 -6.62048848 -3.51511383 -3.69548016 -2.41200419 -2.39543686
#  -1.54797716 -2.92216648 -2.57553263 -1.75219977 -1.00704762]
# margin maxs [ 1.800046    3.14316907  2.16036124  2.45543834  2.34209882  2.46471116
#  -0.3075505   1.57648926  1.8311223   1.65054534  0.83554704]
# margin means [-0.75175092 -0.7100735  -0.57823835 -0.51286951 -0.53700732 -0.5601138
#  -1.00592671 -0.81570449 -0.68077323 -0.38767396 -0.38845153]
# margin abs means [ 0.97884741  0.96928592  0.80985544  0.71798     0.81502699  0.84619476
#   1.00592671  0.96937256  0.90727604  0.56967075  0.39883846]
# margin stds [ 0.97780302  1.12912423  0.88001345  0.69150177  0.83233822  0.86179007
#   0.23665097  0.8783392   0.85307822  0.58524973  0.11812345]
# Superclassifier ROC: 0.721310
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Logregr coefs [[  3.62514716e-02   1.56010802e-01   6.70719707e-01   7.43617298e-01
#     2.57797511e-01   1.20397722e-01  -1.79698326e-01  -1.15153877e-03
#    -7.23779724e-03   1.82492169e+00   2.79032160e+00]]
# Fitted
# Kernel type: linear ROC: 0.775357
# Kernel type: poly, degree = 2 ROC: 0.641786
# Kernel type: poly, degree = 3 ROC: 0.762262
# Kernel type: poly, degree = 4 ROC: 0.654405
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.772976
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.760000
# Kernel type: rbf, gamma = 0.000100 ROC: 0.772262
# Kernel type: rbf, gamma = 0.001000 ROC: 0.779762
# Kernel type: rbf, gamma = 0.010000 ROC: 0.777619
# Kernel type: rbf, gamma = 0.100000 ROC: 0.762143
# Kernel type: rbf, gamma = 1.000000 ROC: 0.713869
# margin mins [-3.76239391 -7.31806827 -4.72281806 -2.18167743 -2.7221777  -2.65958745
#  -1.60450188 -3.19790314 -2.71067054 -2.30927602 -0.91164997]
# margin maxs [ 1.74356856  3.59245796  2.12103159  2.6339313   1.62963306  1.86576659
#  -0.36777046  1.33668047  1.74579264  1.68733627  0.83556175]
# margin means [-0.80393212 -0.74176345 -0.70602277 -0.57927323 -0.70517972 -0.72333885
#  -1.01752147 -0.8872328  -0.79862481 -0.57986036 -0.40423183]
# margin abs means [ 1.05868779  1.09142986  0.97392221  0.82367235  0.99044324  1.02053288
#   1.01752147  1.05268757  1.00790857  0.75242028  0.41259539]
# margin stds [ 0.9997273   1.23657634  0.98961312  0.75829904  0.93573273  0.95239641
#   0.24095447  0.88560482  0.8978708   0.67887029  0.11442101]
# Superclassifier ROC: 0.761190
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Logregr coefs [[ 0.05671846  0.16291353  0.64598158  0.70788315  0.32574489  0.26936978
#   -0.23697751 -0.10132598 -0.05467385  1.73806201  2.87758775]]
# Fitted
# Kernel type: linear ROC: 0.825952
# Kernel type: poly, degree = 2 ROC: 0.634643
# Kernel type: poly, degree = 3 ROC: 0.719286
# Kernel type: poly, degree = 4 ROC: 0.698214
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.776071
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.767500
# Kernel type: rbf, gamma = 0.000100 ROC: 0.826667
# Kernel type: rbf, gamma = 0.001000 ROC: 0.830000
# Kernel type: rbf, gamma = 0.010000 ROC: 0.822143
# Kernel type: rbf, gamma = 0.100000 ROC: 0.734048
# Kernel type: rbf, gamma = 1.000000 ROC: 0.677143
# margin mins [-2.63046102 -5.11060945 -2.99710047 -3.23652791 -2.30100294 -2.26061987
#  -1.3543922  -2.37528107 -2.40119473 -1.75885656 -0.97951573]
# margin maxs [ 1.90376299  3.61224205  3.23548208  3.62808281  3.59720483  3.58960971
#  -0.44736384  1.7855343   2.51462564  1.68056721  0.16737683]
# margin means [-0.72924608 -0.72426168 -0.55388315 -0.57733142 -0.58871306 -0.58544243
#  -1.00256488 -0.81844176 -0.69457735 -0.45948121 -0.4063936 ]
# margin abs means [ 0.96152866  1.04239805  0.87580663  0.76279234  0.87508741  0.8929957
#   1.00256488  0.98471491  0.94326013  0.65587745  0.40806736]
# margin stds [ 0.88800335  1.13495633  0.92651324  0.71265242  0.882892    0.89564851
#   0.1732189   0.8167894   0.87985533  0.65506905  0.07849939]
# Superclassifier ROC: 0.748929
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Logregr coefs [[ -1.08748694e-02   6.09398597e-02   6.64142778e-01   6.65373233e-01
#     2.95794796e-01   2.48301659e-01  -1.80786488e-01  -1.05018448e-05
#    -1.30688816e-01   1.59221881e+00   3.07346791e+00]]
# Fitted
# Kernel type: linear ROC: 0.761548
# Kernel type: poly, degree = 2 ROC: 0.675119
# Kernel type: poly, degree = 3 ROC: 0.709048
# Kernel type: poly, degree = 4 ROC: 0.739762
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.779524
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.777619
# Kernel type: rbf, gamma = 0.000100 ROC: 0.759048
# Kernel type: rbf, gamma = 0.001000 ROC: 0.766548
# Kernel type: rbf, gamma = 0.010000 ROC: 0.784286
# Kernel type: rbf, gamma = 0.100000 ROC: 0.758810
# Kernel type: rbf, gamma = 1.000000 ROC: 0.648750
# margin mins [-2.71829892 -3.53152762 -3.14644342 -2.31147783 -2.37701997 -2.40586449
#  -1.55711272 -2.7056585  -2.54950643 -2.3741459  -0.75438052]
# margin maxs [ 1.51585658  2.56155056  3.30376406  2.01473499  1.82244564  1.75566675
#  -0.28437823  1.24920772  1.42410687  1.49995192  0.16706905]
# margin means [-0.74114535 -0.46239993 -0.51496761 -0.44670637 -0.55197864 -0.57642313
#  -0.99435744 -0.78931779 -0.64184782 -0.40378529 -0.40012068]
# margin abs means [ 0.97356008  0.93701871  0.86664165  0.73584939  0.88063607  0.89634527
#   0.99435744  0.96152686  0.91310215  0.61957123  0.40179137]
# margin stds [ 0.93902789  1.07259384  0.94241593  0.73290611  0.88924615  0.89368094
#   0.26189718  0.87698623  0.86663467  0.65761317  0.06849319]
# Superclassifier ROC: 0.757738
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Logregr coefs [[ 0.03265095  0.06250525  0.67867863  0.63915086  0.35151539  0.24534176
#   -0.20805801 -0.03963866 -0.05271246  1.65287725  2.97712121]]
# Fitted
# Kernel type: linear ROC: 0.819524
# Kernel type: poly, degree = 2 ROC: 0.644286
# Kernel type: poly, degree = 3 ROC: 0.720238
# Kernel type: poly, degree = 4 ROC: 0.689524
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.791548
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.801071
# Kernel type: rbf, gamma = 0.000100 ROC: 0.830833
# Kernel type: rbf, gamma = 0.001000 ROC: 0.829405
# Kernel type: rbf, gamma = 0.010000 ROC: 0.806071
# Kernel type: rbf, gamma = 0.100000 ROC: 0.708452
# Kernel type: rbf, gamma = 1.000000 ROC: 0.651667
# margin mins [-3.11608916 -5.6834756  -3.8326232  -2.22749894 -2.09463319 -2.2916669
#  -1.44602878 -2.84242956 -2.36996348 -2.36070964 -0.68226242]
# margin maxs [ 2.22971998  3.42206271  3.37884942  2.51564607  1.92477563  2.02447654
#  -0.44514307  1.72047661  2.0677859   1.20125969 -0.18019819]
# margin means [-0.70730173 -0.69212859 -0.53822708 -0.52580035 -0.56113939 -0.56628537
#  -0.99039265 -0.78904719 -0.63992735 -0.42720422 -0.40324343]
# margin abs means [ 1.02827234  1.20153892  0.91149267  0.76671874  0.8360262   0.86167147
#   0.99039265  1.01881724  0.94021771  0.59700587  0.40324343]
# margin stds [ 1.01049986  1.3785718   1.02079246  0.7271821   0.81154988  0.84238845
#   0.19592108  0.91529398  0.90225923  0.615751    0.04568989]
# Superclassifier ROC: 0.746667
# TESTING SPAMBASE
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/svm/base.py:224: ConvergenceWarning: Solver terminated early (max_iter=1000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Logregr coefs [[  9.58353381e-01   2.74581240e-01   3.84503799e-01  -3.55302721e-03
#     5.50467263e-01   3.23192205e-01  -7.77035248e-01   2.76369946e-01
#     4.97221162e-02   1.26204314e+00   4.03227335e+00]]
# Fitted
# Kernel type: linear ROC: 0.970085
# Kernel type: poly, degree = 2 ROC: 0.948224
# Kernel type: poly, degree = 3 ROC: 0.950164
# Kernel type: poly, degree = 4 ROC: 0.925079
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.978235
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.979124
# Kernel type: rbf, gamma = 0.000100 ROC: 0.956404
# Kernel type: rbf, gamma = 0.001000 ROC: 0.962383
# Kernel type: rbf, gamma = 0.010000 ROC: 0.972864
# Kernel type: rbf, gamma = 0.100000 ROC: 0.952242
# Kernel type: rbf, gamma = 1.000000 ROC: 0.906857
# margin mins [-14.43841539 -44.12259865 -32.87093369 -55.87311637  -2.74703625
#   -3.08619522  -5.03469773  -4.79825382  -3.73847282  -2.72606262
#   -1.6035862 ]
# margin maxs [  17.33492721   24.52413812   58.23091854  186.7676207     2.02547839
#     1.96513274    4.83326066    3.93808368    2.21482153    2.4207936
#     1.15341143]
# margin means [-0.57356574 -0.44595378 -0.15331415  0.0872151  -0.34673453 -0.34688168
#  -0.38951769 -0.35326681 -0.33295177 -0.25451866 -0.21020725]
# margin abs means [ 0.95129422  0.89518669  0.77072959  0.6136089   0.98830323  1.00049072
#   0.96948666  1.00050767  0.98474063  0.82247386  0.43561643]
# margin stds [ 1.89974287  2.72285682  2.84793991  6.70178745  1.06959468  1.10075421
#   1.14675854  1.22681395  1.11924119  0.94794916  0.49221541]
# Superclassifier ROC: 0.966648
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Logregr coefs [[ 0.76327636  0.22411795  0.29161627  0.07156385  0.56102908  0.58593695
#   -0.59081333  0.1935271   0.40041525  0.96842536  4.13866057]]
# Fitted
# Kernel type: linear ROC: 0.980405
# Kernel type: poly, degree = 2 ROC: 0.952877
# Kernel type: poly, degree = 3 ROC: 0.952215
# Kernel type: poly, degree = 4 ROC: 0.934896
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.979581
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.981911
# Kernel type: rbf, gamma = 0.000100 ROC: 0.967377
# Kernel type: rbf, gamma = 0.001000 ROC: 0.977295
# Kernel type: rbf, gamma = 0.010000 ROC: 0.976851
# Kernel type: rbf, gamma = 0.100000 ROC: 0.945037
# Kernel type: rbf, gamma = 1.000000 ROC: 0.905141
# margin mins [-16.19711431 -53.01516609 -38.88849917 -74.31040033  -2.37583367
#   -2.61912082  -5.11272954  -4.83883165  -2.86490642  -2.59270932
#   -2.06990309]
# margin maxs [  2.6546007    7.38912532  16.29156228  19.21679247   2.77399625
#    2.6217764    4.36760278   3.56239028   2.51739132   2.88273866
#    1.12897033]
# margin means [-0.57527755 -0.54216816 -0.21946571 -0.27659083 -0.27810415 -0.29541697
#  -0.29492423 -0.2708025  -0.30388912 -0.23640002 -0.19591631]
# margin abs means [ 0.98558799  1.08208193  0.85371099  0.64293849  1.02279556  1.0364399
#   1.03966505  1.0556838   1.02737503  0.82290218  0.47883172]
# margin stds [ 1.89412885  3.78614016  2.85124767  4.71832252  1.10990113  1.13997735
#   1.22751652  1.28338288  1.15550871  0.93248589  0.54882949]
# Superclassifier ROC: 0.968794
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Logregr coefs [[ 1.06686402  0.23836876  0.33678773  0.1414992   0.62564394  0.54761586
#   -1.11127491  0.21955612  0.2914389   0.85867479  4.32180071]]
# Fitted
# Kernel type: linear ROC: 0.954427
# Kernel type: poly, degree = 2 ROC: 0.951682
# Kernel type: poly, degree = 3 ROC: 0.958564
# Kernel type: poly, degree = 4 ROC: 0.942958
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.982918
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.983644
# Kernel type: rbf, gamma = 0.000100 ROC: 0.963955
# Kernel type: rbf, gamma = 0.001000 ROC: 0.975730
# Kernel type: rbf, gamma = 0.010000 ROC: 0.982104
# Kernel type: rbf, gamma = 0.100000 ROC: 0.967041
# Kernel type: rbf, gamma = 1.000000 ROC: 0.927955
# margin mins [-13.60395607 -54.190562   -47.73809685 -73.83763216  -2.5044246
#   -2.68168692  -4.64022497  -4.83657023  -3.25787717  -2.41161561
#   -2.44091232]
# margin maxs [ 14.18223483  13.56012363  43.58058316  54.06365209   2.03591337
#    2.15443507   3.89653184   3.85085766   2.2315073    2.03877552
#    1.10662878]
# margin means [-0.44197876 -0.47085125 -0.16752379 -0.16133772 -0.23679612 -0.22577019
#  -0.25085074 -0.20646594 -0.2069065  -0.20304473 -0.23056825]
# margin abs means [ 0.91058477  1.05505725  0.99880901  0.80424267  0.95314992  0.96708255
#   1.02069214  1.02585805  0.93113676  0.77509324  0.50962789]
# margin stds [ 1.73552344  3.72898859  3.69453172  5.13050748  1.04860675  1.07888727
#   1.21902399  1.2547569   1.07404448  0.87894582  0.56636502]
# Superclassifier ROC: 0.973666
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Logregr coefs [[ 1.03246121  0.19456954  0.31005949 -0.03864343  0.4824115   0.43099785
#   -0.79625866  0.19685811  0.15298026  0.87604291  4.47630592]]
# Fitted
# Kernel type: linear ROC: 0.984432
# Kernel type: poly, degree = 2 ROC: 0.963335
# Kernel type: poly, degree = 3 ROC: 0.968393
# Kernel type: poly, degree = 4 ROC: 0.956778
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.992228
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.992228
# Kernel type: rbf, gamma = 0.000100 ROC: 0.976492
# Kernel type: rbf, gamma = 0.001000 ROC: 0.985007
# Kernel type: rbf, gamma = 0.010000 ROC: 0.988345
# Kernel type: rbf, gamma = 0.100000 ROC: 0.967649
# Kernel type: rbf, gamma = 1.000000 ROC: 0.927832
# margin mins [-14.6694028  -43.17552925 -35.34130603 -46.27284834  -2.64092834
#   -2.6872627   -5.18526225  -4.01441701  -3.0433875   -2.44908666
#   -1.59454512]
# margin maxs [  10.42553844   29.89119966  140.04797111  378.36430312    2.03260876
#     2.13806394    5.0115841     3.14672904    2.61201089    2.4066269
#     1.07918191]
# margin means [-1.10670704 -0.57110889  0.00322938  0.4891938  -0.40270488 -0.42070681
#  -0.30436265 -0.31408127 -0.44721775 -0.28674304 -0.28350407]
# margin abs means [ 1.67918583  1.23807207  1.34391227  1.54092264  1.07719918  1.10601025
#   1.07173619  1.11623886  1.14235413  0.80289151  0.52641579]
# margin stds [  2.94298313   4.07972607   6.01666438  13.94432962   1.15367835
#    1.20060555   1.26214188   1.33196457   1.31283691   0.89225064
#    0.55948772]
# Superclassifier ROC: 0.983232
# Fitted Kernel type: linear
# Fitted Kernel type: poly, degree = 2
# Fitted Kernel type: poly, degree = 3
# Fitted Kernel type: poly, degree = 4
# Fitted Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Fitted Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Fitted Kernel type: rbf, gamma = 0.000100
# Fitted Kernel type: rbf, gamma = 0.001000
# Fitted Kernel type: rbf, gamma = 0.010000
# Fitted Kernel type: rbf, gamma = 0.100000
# Fitted Kernel type: rbf, gamma = 1.000000
# Margins calculated
# Logregr coefs [[ 1.20943927  0.26748843  0.47543013  0.09772239  0.54687487  0.39085926
#   -0.88796416  0.15498854  0.43564415  1.53867847  3.46929622]]
# Fitted
# Kernel type: linear ROC: 0.875869
# Kernel type: poly, degree = 2 ROC: 0.862558
# Kernel type: poly, degree = 3 ROC: 0.850397
# Kernel type: poly, degree = 4 ROC: 0.840225
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000 ROC: 0.919379
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000 ROC: 0.918451
# Kernel type: rbf, gamma = 0.000100 ROC: 0.874639
# Kernel type: rbf, gamma = 0.001000 ROC: 0.893490
# Kernel type: rbf, gamma = 0.010000 ROC: 0.904401
# Kernel type: rbf, gamma = 0.100000 ROC: 0.860646
# Kernel type: rbf, gamma = 1.000000 ROC: 0.762476
# margin mins [ -8.3083126  -17.35392625 -16.77984849 -15.22432667  -1.71403256
#   -1.74829921  -2.63178091  -3.09381036  -1.93578656  -2.13675863
#   -2.03056517]
# margin maxs [  11.44630652   26.49822079  182.79987883  531.9960314     1.76270564
#     1.92134416    7.38244963    3.62902006    2.23197924    2.07033637
#     1.43735053]
# margin means [ 0.17912344  0.04812274  0.65154326  1.61042083 -0.05125072 -0.03047621
#   0.04462711  0.09568498  0.00202132 -0.17184625 -0.22064987]
# margin abs means [ 0.61250479  0.63756702  1.03183337  1.85885724  0.70476743  0.69540582
#   0.74119912  0.70053469  0.68351478  0.67388166  0.36420707]
# margin stds [  1.42664359   1.70020106   8.35972013  24.87372156   0.80919098
#    0.8090556    0.98867281   0.91355966   0.81849913   0.80205078
#    0.37234792]
# Superclassifier ROC: 0.878128
