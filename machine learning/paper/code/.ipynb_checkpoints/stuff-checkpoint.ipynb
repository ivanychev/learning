# %%
import utils
import sys
import pandas as pd
import classifiers
from matplotlib import pylab as pl
import numpy as np
from metric import clf_symdiff_normalized
from metric import clf_symdiff
import matplotlib
# %matplotlib inline

font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 16}

# matplotlib.rc('font', **font)
matplotlib.rc('text', usetex=True)

# %% [markdown]
# ## Readme
#
# Kernel set is specified in `get_classifier_specs()` procedure. `get_data` returns a dictionary like `{"dataset_name":(X, Y), ...}`. Margins are calculated for each kernel via `SVC.decision.function()` method
#
# __Note__: INK-spline SVM learning process usually takes a lot of time.

# %% [markdown]
# ## Calculating and drawing here

# %%
CLF_DIFF_TYPES = {
    "sn": ("SV normalized symmetric difference", clf_symdiff_normalized),
    "s": ("SV symmetric difference", clf_symdiff)
}

TEX_TABLE_BEGIN = """
\\begin{table}[H]
\\centering
\\caption{$$$$$}
\\label{my-label}
\\begin{tabular}{|l|l|l|l|l|}
\\hline
         & $\\mathrm{mean}(\\#\\mathrm{SV})$ & $\\mathrm{mean}(1 - \\mathrm{corr}(M_i, M_j))$ & $\\mathrm{mean}(\\rho_{X^l}(K_i, K_j))$ & Correlation \\\\ \\hline
"""

TEX_TABLE_END = """
\\end{tabular}
\\end{table}
"""
def margin_cov_pic(margins, clfs, C, fig, tex_info, diff_type = "sn"):
    diff = CLF_DIFF_TYPES[diff_type][1]
    clfs_num = len(clfs)
    corrs_num = round(clfs_num * (clfs_num - 1) / 2)
    corrs = np.zeros(corrs_num)
    difs = np.zeros(corrs_num)
    idx = 0
    for i in range(clfs_num):
        for j in range(i + 1, clfs_num):
            corrs[idx] = np.corrcoef(margins[:, i], margins[:, j])[0, 1]
            difs[idx] = diff(clfs[i], clfs[j])
            idx += 1
    scatter_legend = "C = %.1f" % C
    fig.scatter(difs, 1 - corrs, marker='o', s=90, label=scatter_legend, c=np.random.rand(3,1))
    sv_mean = sum([clf.n_support_[0] + clf.n_support_[1] for clf in clfs])/len(clfs)
    corr_mean = (1 - corrs).mean()
    dif_mean = difs.mean()
    corr_of_scatter = np.corrcoef((1 - corrs), difs)[0, 1]
    info = "$C=%.1f$ & $%.1f$ & $%.3f$ & $%.3f$ & $%.3f$\\\\ \\hline" %(C, sv_mean, corr_mean, dif_mean, corr_of_scatter)
    tex_info.append(info)
    return corr_mean, dif_mean

    
def spec_repr(spec):
    ret = "Kernel type: "
    if spec[0] == "linear":
        return ret + "linear"
    if spec[0] == "rbf":
        return ret + "rbf, gamma = %f" % spec[1]
    if spec[0] == "poly":
        return ret + "poly, degree = %d" % spec[1]
    if spec[0] == "ink":
        return ret + "ink, degree = %d, downer limit (a) = %f" % (spec[1], spec[2])

def print_kernel_info(C, clfs, specs, margins):
    print("C = %f" % C)
    for idx, clf in enumerate(clfs):
        print("%s\nSV number = %d" % (spec_repr(specs[idx]), clf.n_support_[0] + clf.n_support_[1]))
    print("")

def _plot_routine(diff_type):
        pl.legend(loc='upper left')
        pl.xlabel(CLF_DIFF_TYPES[diff_type][0])
        pl.ylabel("$1 - \mathrf{corr}(M_i, M_j)$")
        pl.xlim(0, 0.6)
        pl.ylim(0, 0.6)
        
def draw_corr_diff(dataset_name, C_list, filename, diff_type = "sn"):
    data = utils.get_data()
    dataset = data[dataset_name]
    print(dataset_name)
    print(dataset[0].shape)
    specs = utils.get_classifier_specs()
    fig = pl.figure(figsize=(16, 9), dpi=300)
    subplots = [(len(C_list) // 2 + len(C_list) % 2, 2, i + 1) for i in range(len(C_list))]
#    subplots = [(1, len(C_list), i + 1) for i in range(len(C_list))]
    tex_info = [TEX_TABLE_BEGIN[:]]
    tex_info[0] = tex_info[0].replace("$$$$$", dataset_name.capitalize() + " info")
    corr_means = np.zeros(len(C_list))
    dif_means = np.zeros(len(C_list))
    for idx, C in enumerate(C_list):
        ax1 = fig.add_subplot(*subplots[idx])
        clfs = classifiers.get(specs, C=C)
        utils.train_clfs(clfs, dataset[0], dataset[1])
        margins = utils.get_margins(clfs, dataset[0])
        print_kernel_info(C, clfs, specs, margins)
        corr_mean, dif_mean = margin_cov_pic(margins, clfs, C, ax1, tex_info, diff_type=diff_type)
        corr_means[idx] = corr_mean
        dif_means[idx] = dif_mean
        _plot_routine(diff_type)
    tex_info.append(TEX_TABLE_END)
    tex_info_table = "\n".join(tex_info)
    with open("../source-paper/%s.tex" % dataset_name + "_table", "w") as f:
        f.write(tex_info_table)
    print("corr_means", corr_means)
    print("dif_means", dif_means)
    print("corr_mean and dif_mean correlation: %f" % np.corrcoef(corr_means, dif_means)[0, 1])
    pl.savefig(filename)

# %% [markdown]
# ## Wine dataset

# %%
draw_corr_diff("wine", [1, 10, 100, 500, 1000, 2500], "../source-paper/wine.pdf")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# wine
# (4898, 11)
# C = 1.000000
# Kernel type: linear
# SV number = 3292
# Kernel type: poly, degree = 2
# SV number = 3280
# Kernel type: poly, degree = 3
# SV number = 3280
# Kernel type: poly, degree = 4
# SV number = 3280
# Kernel type: rbf, gamma = 0.000100
# SV number = 3280
# Kernel type: rbf, gamma = 0.001000
# SV number = 3280
# Kernel type: rbf, gamma = 0.010000
# SV number = 3283
# Kernel type: rbf, gamma = 0.100000
# SV number = 3294
# Kernel type: rbf, gamma = 1.000000
# SV number = 3288
#
# C = 10.000000
# Kernel type: linear
# SV number = 3287
# Kernel type: poly, degree = 2
# SV number = 3290
# Kernel type: poly, degree = 3
# SV number = 3280
# Kernel type: poly, degree = 4
# SV number = 3280
# Kernel type: rbf, gamma = 0.000100
# SV number = 3280
# Kernel type: rbf, gamma = 0.001000
# SV number = 3288
# Kernel type: rbf, gamma = 0.010000
# SV number = 3296
# Kernel type: rbf, gamma = 0.100000
# SV number = 3287
# Kernel type: rbf, gamma = 1.000000
# SV number = 3276
#
# C = 100.000000
# Kernel type: linear
# SV number = 3269
# Kernel type: poly, degree = 2
# SV number = 3291
# Kernel type: poly, degree = 3
# SV number = 3290
# Kernel type: poly, degree = 4
# SV number = 3281
# Kernel type: rbf, gamma = 0.000100
# SV number = 3283
# Kernel type: rbf, gamma = 0.001000
# SV number = 3295
# Kernel type: rbf, gamma = 0.010000
# SV number = 3290
# Kernel type: rbf, gamma = 0.100000
# SV number = 3280
# Kernel type: rbf, gamma = 1.000000
# SV number = 3196
#
# C = 500.000000
# Kernel type: linear
# SV number = 3201
# Kernel type: poly, degree = 2
# SV number = 3285
# Kernel type: poly, degree = 3
# SV number = 3288
# Kernel type: poly, degree = 4
# SV number = 3287
# Kernel type: rbf, gamma = 0.000100
# SV number = 3292
# Kernel type: rbf, gamma = 0.001000
# SV number = 3289
# Kernel type: rbf, gamma = 0.010000
# SV number = 3288
# Kernel type: rbf, gamma = 0.100000
# SV number = 3266
# Kernel type: rbf, gamma = 1.000000
# SV number = 3077
#
# C = 1000.000000
# Kernel type: linear
# SV number = 3147
# Kernel type: poly, degree = 2
# SV number = 3280
# Kernel type: poly, degree = 3
# SV number = 3288
# Kernel type: poly, degree = 4
# SV number = 3290
# Kernel type: rbf, gamma = 0.000100
# SV number = 3291
# Kernel type: rbf, gamma = 0.001000
# SV number = 3286
# Kernel type: rbf, gamma = 0.010000
# SV number = 3284
# Kernel type: rbf, gamma = 0.100000
# SV number = 3235
# Kernel type: rbf, gamma = 1.000000
# SV number = 3016
#
# C = 2500.000000
# Kernel type: linear
# SV number = 3066
# Kernel type: poly, degree = 2
# SV number = 3270
# Kernel type: poly, degree = 3
# SV number = 3282
# Kernel type: poly, degree = 4
# SV number = 3287
# Kernel type: rbf, gamma = 0.000100
# SV number = 3285
# Kernel type: rbf, gamma = 0.001000
# SV number = 3286
# Kernel type: rbf, gamma = 0.010000
# SV number = 3275
# Kernel type: rbf, gamma = 0.100000
# SV number = 3181
# Kernel type: rbf, gamma = 1.000000
# SV number = 2945
#
# corr_means [ 0.21964806  0.12991414  0.09138823  0.11047526  0.1240102   0.12716283]
# dif_means [ 0.14444589  0.12069402  0.09125046  0.10518577  0.11750974  0.13266397]
# corr_mean and dif_mean correlation: 0.854561

# %% [markdown]
# ## German dataset

# %%
draw_corr_diff("german", [1, 10, 100, 500, 1000, 2500], "../source-paper/german.pdf")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# german
# (1000, 24)
# C = 1.000000
# Kernel type: linear
# SV number = 606
# Kernel type: poly, degree = 2
# SV number = 600
# Kernel type: poly, degree = 3
# SV number = 600
# Kernel type: poly, degree = 4
# SV number = 600
# Kernel type: rbf, gamma = 0.000100
# SV number = 600
# Kernel type: rbf, gamma = 0.001000
# SV number = 600
# Kernel type: rbf, gamma = 0.010000
# SV number = 608
# Kernel type: rbf, gamma = 0.100000
# SV number = 608
# Kernel type: rbf, gamma = 1.000000
# SV number = 609
#
# C = 10.000000
# Kernel type: linear
# SV number = 605
# Kernel type: poly, degree = 2
# SV number = 608
# Kernel type: poly, degree = 3
# SV number = 600
# Kernel type: poly, degree = 4
# SV number = 600
# Kernel type: rbf, gamma = 0.000100
# SV number = 600
# Kernel type: rbf, gamma = 0.001000
# SV number = 606
# Kernel type: rbf, gamma = 0.010000
# SV number = 610
# Kernel type: rbf, gamma = 0.100000
# SV number = 610
# Kernel type: rbf, gamma = 1.000000
# SV number = 593
#
# C = 100.000000
# Kernel type: linear
# SV number = 578
# Kernel type: poly, degree = 2
# SV number = 607
# Kernel type: poly, degree = 3
# SV number = 608
# Kernel type: poly, degree = 4
# SV number = 600
# Kernel type: rbf, gamma = 0.000100
# SV number = 607
# Kernel type: rbf, gamma = 0.001000
# SV number = 606
# Kernel type: rbf, gamma = 0.010000
# SV number = 606
# Kernel type: rbf, gamma = 0.100000
# SV number = 597
# Kernel type: rbf, gamma = 1.000000
# SV number = 543
#
# C = 500.000000
# Kernel type: linear
# SV number = 556
# Kernel type: poly, degree = 2
# SV number = 606
# Kernel type: poly, degree = 3
# SV number = 607
# Kernel type: poly, degree = 4
# SV number = 600
# Kernel type: rbf, gamma = 0.000100
# SV number = 608
# Kernel type: rbf, gamma = 0.001000
# SV number = 607
# Kernel type: rbf, gamma = 0.010000
# SV number = 606
# Kernel type: rbf, gamma = 0.100000
# SV number = 565
# Kernel type: rbf, gamma = 1.000000
# SV number = 504
#
# C = 1000.000000
# Kernel type: linear
# SV number = 553
# Kernel type: poly, degree = 2
# SV number = 606
# Kernel type: poly, degree = 3
# SV number = 609
# Kernel type: poly, degree = 4
# SV number = 605
# Kernel type: rbf, gamma = 0.000100
# SV number = 604
# Kernel type: rbf, gamma = 0.001000
# SV number = 607
# Kernel type: rbf, gamma = 0.010000
# SV number = 598
# Kernel type: rbf, gamma = 0.100000
# SV number = 552
# Kernel type: rbf, gamma = 1.000000
# SV number = 500
#
# C = 2500.000000
# Kernel type: linear
# SV number = 544
# Kernel type: poly, degree = 2
# SV number = 608
# Kernel type: poly, degree = 3
# SV number = 610
# Kernel type: poly, degree = 4
# SV number = 607
# Kernel type: rbf, gamma = 0.000100
# SV number = 605
# Kernel type: rbf, gamma = 0.001000
# SV number = 606
# Kernel type: rbf, gamma = 0.010000
# SV number = 586
# Kernel type: rbf, gamma = 0.100000
# SV number = 542
# Kernel type: rbf, gamma = 1.000000
# SV number = 493
#
# corr_means [ 0.18413215  0.18719587  0.13418175  0.13304708  0.12008995  0.12556725]
# dif_means [ 0.0937099   0.09664406  0.13104549  0.16128207  0.17182274  0.18873713]
# corr_mean and dif_mean correlation: -0.923979

# %% [markdown]
# ## Heart dataset

# %%
draw_corr_diff("heart", [1, 10, 100, 500, 1000, 2500], "../source-paper/heart.pdf")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# heart
# (297, 13)
# C = 1.000000
# Kernel type: linear
# SV number = 272
# Kernel type: poly, degree = 2
# SV number = 274
# Kernel type: poly, degree = 3
# SV number = 274
# Kernel type: poly, degree = 4
# SV number = 274
# Kernel type: rbf, gamma = 0.000100
# SV number = 274
# Kernel type: rbf, gamma = 0.001000
# SV number = 274
# Kernel type: rbf, gamma = 0.010000
# SV number = 274
# Kernel type: rbf, gamma = 0.100000
# SV number = 274
# Kernel type: rbf, gamma = 1.000000
# SV number = 258
#
# C = 10.000000
# Kernel type: linear
# SV number = 227
# Kernel type: poly, degree = 2
# SV number = 274
# Kernel type: poly, degree = 3
# SV number = 274
# Kernel type: poly, degree = 4
# SV number = 274
# Kernel type: rbf, gamma = 0.000100
# SV number = 274
# Kernel type: rbf, gamma = 0.001000
# SV number = 274
# Kernel type: rbf, gamma = 0.010000
# SV number = 274
# Kernel type: rbf, gamma = 0.100000
# SV number = 256
# Kernel type: rbf, gamma = 1.000000
# SV number = 220
#
# C = 100.000000
# Kernel type: linear
# SV number = 205
# Kernel type: poly, degree = 2
# SV number = 270
# Kernel type: poly, degree = 3
# SV number = 275
# Kernel type: poly, degree = 4
# SV number = 274
# Kernel type: rbf, gamma = 0.000100
# SV number = 274
# Kernel type: rbf, gamma = 0.001000
# SV number = 274
# Kernel type: rbf, gamma = 0.010000
# SV number = 256
# Kernel type: rbf, gamma = 0.100000
# SV number = 220
# Kernel type: rbf, gamma = 1.000000
# SV number = 194
#
# C = 500.000000
# Kernel type: linear
# SV number = 170
# Kernel type: poly, degree = 2
# SV number = 234
# Kernel type: poly, degree = 3
# SV number = 275
# Kernel type: poly, degree = 4
# SV number = 274
# Kernel type: rbf, gamma = 0.000100
# SV number = 274
# Kernel type: rbf, gamma = 0.001000
# SV number = 272
# Kernel type: rbf, gamma = 0.010000
# SV number = 227
# Kernel type: rbf, gamma = 0.100000
# SV number = 205
# Kernel type: rbf, gamma = 1.000000
# SV number = 156
#
# C = 1000.000000
# Kernel type: linear
# SV number = 155
# Kernel type: poly, degree = 2
# SV number = 225
# Kernel type: poly, degree = 3
# SV number = 266
# Kernel type: poly, degree = 4
# SV number = 275
# Kernel type: rbf, gamma = 0.000100
# SV number = 274
# Kernel type: rbf, gamma = 0.001000
# SV number = 256
# Kernel type: rbf, gamma = 0.010000
# SV number = 220
# Kernel type: rbf, gamma = 0.100000
# SV number = 193
# Kernel type: rbf, gamma = 1.000000
# SV number = 144
#
# C = 2500.000000
# Kernel type: linear
# SV number = 139
# Kernel type: poly, degree = 2
# SV number = 217
# Kernel type: poly, degree = 3
# SV number = 246
# Kernel type: poly, degree = 4
# SV number = 275
# Kernel type: rbf, gamma = 0.000100
# SV number = 274
# Kernel type: rbf, gamma = 0.001000
# SV number = 236
# Kernel type: rbf, gamma = 0.010000
# SV number = 213
# Kernel type: rbf, gamma = 0.100000
# SV number = 170
# Kernel type: rbf, gamma = 1.000000
# SV number = 133
#
# corr_means [ 0.00347697  0.01983931  0.06325536  0.13485794  0.15728268  0.16625872]
# dif_means [ 0.02662919  0.08808933  0.15156792  0.23842407  0.2675139   0.29743001]
# corr_mean and dif_mean correlation: 0.990561

# %%
from sklearn.preprocessing import normalize
def load(path: str ="../data/spambase") \
-> (np.ndarray, np.ndarray):
    """
    :param path:    relative path to the folder that contains files such as
                        - spambase.data
    :return:        X   (samples x n_features)  numpy.ndarray
                    Y   (samples, )             numpy.ndarray
    """
    names = [str(i + 1) for i in range(58)]
    df = pd.read_csv(path + "/spambase.data",
                     sep=",", index_col=False, engine='python', names=names)
    target = "57"
    features_names = names[:]
    features_names.remove(target)

    X = df[features_names].as_matrix()
    Y = df[target].as_matrix()

    return np.normalize(X), Y, "german"

# %%
load()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-d9071ca35cb3> in <module>()
# ----> 1 load()
#
# <ipython-input-17-90367fd09bdb> in load(path)
#      16     Y = df[target].as_matrix()
#      17
# ---> 18     return np.normalize(X), Y, "german"
#
# AttributeError: module 'numpy' has no attribute 'normalize'
