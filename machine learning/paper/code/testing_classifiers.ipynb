# %%
import utils
from utils import test_classifier
from utils import test_classifiers
from sklearn.preprocessing import StandardScaler
import warnings
import numpy as np
from functools import partial
from scipy.misc import comb
import spam

# %%
for dataset in utils.datasets:
    test_classifiers(dataset)
# Out:
# Testing german dataset...
# Folds = 5, Folds type = stratified
# Kernel type: linear
# Score = 0.790976, std = 0.030561
# Kernel type: poly, degree = 2
# Score = 0.647167, std = 0.055626
# Kernel type: poly, degree = 3
# Score = 0.767619, std = 0.020767
# Kernel type: poly, degree = 4
# Score = 0.696381, std = 0.060126
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Score = 0.792190, std = 0.038310
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Score = 0.788857, std = 0.038447
# Kernel type: rbf, gamma = 0.000100
# Score = 0.789583, std = 0.032140
# Kernel type: rbf, gamma = 0.001000
# Score = 0.791905, std = 0.030597
# Kernel type: rbf, gamma = 0.001000
# Score = 0.791905, std = 0.030597
# Kernel type: rbf, gamma = 0.010000
# Score = 0.795143, std = 0.030600
# Kernel type: rbf, gamma = 0.100000
# Score = 0.764643, std = 0.013357
# Kernel type: rbf, gamma = 1.000000
# Score = 0.655000, std = 0.043308
# Testing german dataset finished
#
# Testing wine dataset...
# Folds = 5, Folds type = stratified
# Kernel type: linear
# Score = 0.795041, std = 0.032932
# Kernel type: poly, degree = 2
# Score = 0.693685, std = 0.036387
# Kernel type: poly, degree = 3
# Score = 0.784578, std = 0.017659
# Kernel type: poly, degree = 4
# Score = 0.727591, std = 0.021864
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Score = 0.810834, std = 0.021949
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Score = 0.808119, std = 0.021308
# Kernel type: rbf, gamma = 0.000100
# Score = 0.783509, std = 0.030479
# Kernel type: rbf, gamma = 0.001000
# Score = 0.785797, std = 0.030647
# Kernel type: rbf, gamma = 0.001000
# Score = 0.785797, std = 0.030647
# Kernel type: rbf, gamma = 0.010000
# Score = 0.795621, std = 0.030712
# Kernel type: rbf, gamma = 0.100000
# Score = 0.809867, std = 0.029005
# Kernel type: rbf, gamma = 1.000000
# Score = 0.767502, std = 0.042880
# Testing wine dataset finished
#
# Testing housing dataset...
# Folds = 5, Folds type = stratified
# Kernel type: linear
# Score = 0.928747, std = 0.041480
# Kernel type: poly, degree = 2
# Score = 0.764572, std = 0.044752
# Kernel type: poly, degree = 3
# Score = 0.888208, std = 0.050867
# Kernel type: poly, degree = 4
# Score = 0.818134, std = 0.044551
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Score = 0.917387, std = 0.042695
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Score = 0.899673, std = 0.047389
# Kernel type: rbf, gamma = 0.000100
# Score = 0.927927, std = 0.042244
# Kernel type: rbf, gamma = 0.001000
# Score = 0.927317, std = 0.040370
# Kernel type: rbf, gamma = 0.001000
# Score = 0.927317, std = 0.040370
# Kernel type: rbf, gamma = 0.010000
# Score = 0.925013, std = 0.040255
# Kernel type: rbf, gamma = 0.100000
# Score = 0.933559, std = 0.023701
# Kernel type: rbf, gamma = 1.000000
# Score = 0.836300, std = 0.024641
# Testing housing dataset finished
#
# Testing spambase dataset...
# Folds = 5, Folds type = stratified
# Kernel type: linear
# Score = 0.956210, std = 0.034388
# Kernel type: poly, degree = 2
# Score = 0.913883, std = 0.010998
# Kernel type: poly, degree = 3
# Score = 0.929441, std = 0.045856
# Kernel type: poly, degree = 4
# Score = 0.906201, std = 0.028993
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Score = 0.958442, std = 0.038813
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Score = 0.957531, std = 0.038924
# Kernel type: rbf, gamma = 0.000100
# Score = 0.928784, std = 0.039941
# Kernel type: rbf, gamma = 0.001000
# Score = 0.933710, std = 0.041905
# Kernel type: rbf, gamma = 0.001000
# Score = 0.933710, std = 0.041905
# Kernel type: rbf, gamma = 0.010000
# Score = 0.951848, std = 0.038357
# Kernel type: rbf, gamma = 0.100000
# Score = 0.929826, std = 0.057434
# Kernel type: rbf, gamma = 1.000000
# Score = 0.888951, std = 0.059245
# Testing spambase dataset finished
#
# Testing heart dataset...
# Folds = 5, Folds type = stratified
# Kernel type: linear
# Score = 0.906143, std = 0.025500
# Kernel type: poly, degree = 2
# Score = 0.683242, std = 0.071019
# Kernel type: poly, degree = 3
# Score = 0.905704, std = 0.031776
# Kernel type: poly, degree = 4
# Score = 0.719279, std = 0.028859
# Kernel type: ink, degree = 1, downer limit (a) = -3.000000
# Score = 0.902009, std = 0.036417
# Kernel type: ink, degree = 2, downer limit (a) = -3.000000
# Score = 0.895933, std = 0.039020
# Kernel type: rbf, gamma = 0.000100
# Score = 0.907416, std = 0.028527
# Kernel type: rbf, gamma = 0.001000
# Score = 0.906969, std = 0.027817
# Kernel type: rbf, gamma = 0.001000
# Score = 0.906969, std = 0.027817
# Kernel type: rbf, gamma = 0.010000
# Score = 0.906994, std = 0.028870
# Kernel type: rbf, gamma = 0.100000
# Score = 0.897388, std = 0.035465
# Kernel type: rbf, gamma = 1.000000
# Score = 0.795139, std = 0.048617
# Testing heart dataset finished
