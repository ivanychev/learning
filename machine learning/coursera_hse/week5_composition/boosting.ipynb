# %% [markdown]
# # Boosting

# %%
import pandas as pd
import numpy as np
from sklearn.cross_validation import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import log_loss
from sklearn.ensemble import RandomForestClassifier
# %matplotlib inline

# %% [markdown]
# > Загрузите выборку из файла gbm-data.csv с помощью pandas и преобразуйте ее в массив numpy (параметр values у датафрейма). В первой колонке файла с данными записано, была или нет реакция. Все остальные колонки (d1 - d1776) содержат различные характеристики молекулы, такие как размер, форма и т.д. Разбейте выборку на обучающую и тестовую, используя функцию train_test_split с параметрами test_size = 0.8 и random_state = 241.

# %%
# !ls
df = pd.read_csv("gbm-data.csv")
df.shape
# Out:
# abalone.csv          gbm-data.csv         tree_size.ipynb
# ans11.txt            statement-forest.pdf
# boosting.ipynb       statement-gbm.pdf
# (3751, 1777)

# %%
data = df.values
y = data[:, 0]
X = data[:, 1:]
X.shape
# Out:
# (3751, 1776)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.8, random_state=241)

# %% [markdown]
# > Обучите GradientBoostingClassifier с параметрами n_estimators=250, verbose=True, random_state=241 и для каждого значения learning_rate из списка [1, 0.5, 0.3, 0.2, 0.1] проделайте следующее:
#
# > * Используйте метод staged_decision_function для предсказания качества на обучающей и тестовой выборке на каждой итерации.
#
# > * Преобразуйте полученное предсказание с помощью сигмоидной функции по формуле 1 / (1 + e^{−y_pred}), где y_pred — предсказаное значение.
#
# > * Вычислите и постройте график значений log-loss (которую можно посчитать с помощью функции sklearn.metrics.log_loss) на обучающей и тестовой выборках, а также найдите минимальное значение метрики и номер итерации, на которой оно достигается.

# %%
for learning_rate in [1, 0.5, 0.3, 0.2, 0.1]:
    cls = GradientBoostingClassifier(n_estimators=250, verbose=True, random_state=241, learning_rate=learning_rate)
    cls.fit(X_train, y_train)
    train_loss = []
    test_loss = []
    for predict in cls.staged_decision_function(X_train):
        predict = 1 / (1 + np.exp(-predict))
        train_loss.append(log_loss(y_train, predict))
    for predict in cls.staged_decision_function(X_test):
        predict = 1 / (1 + np.exp(-predict))
        test_loss.append(log_loss(y_test, predict))
    plt.figure()
    plt.plot(test_loss, 'r', linewidth=2)
    plt.plot(train_loss, 'g', linewidth=2)
    plt.legend(['test', 'train'])
    plt.show()
    print("^ learning rate: %f, minimum test_loss = %d:%s" % (learning_rate, test_loss.index(min(test_loss)), min(test_loss)))
# Out:
#       Iter       Train Loss   Remaining Time
#          1           1.0190           21.98s
#          2           0.9192           22.25s
#          3           0.8272           22.19s
#          4           0.7834           20.80s
#          5           0.7109           20.24s
#          6           0.6368           20.97s
#          7           0.5797           22.07s
#          8           0.5610           21.75s
#          9           0.5185           21.34s
#         10           0.4984           20.72s
#         20           0.1999           18.80s
#         30           0.1313           16.16s
#         40           0.0790           14.18s
#         50           0.0511           13.07s
#         60           0.0352           12.06s
#         70           0.0245           11.14s
#         80           0.0162           10.33s
#         90           0.0114            9.53s
#        100           0.0077            9.04s
#        200           0.0004            2.52s
# ^ learning rate: 1.000000, minimum test_loss = 0:0.582294259428
#       Iter       Train Loss   Remaining Time
#          1           1.1255           18.71s
#          2           1.0035           19.35s
#          3           0.9386           19.90s
#          4           0.8844           19.63s
#          5           0.8381           19.46s
#          6           0.7995           20.19s
#          7           0.7559           21.21s
#          8           0.7205           22.20s
#          9           0.6958           23.12s
#         10           0.6725           24.05s
#         20           0.4672           18.69s
#         30           0.3179           16.38s
#         40           0.2274           14.50s
#         50           0.1774           13.33s
#         60           0.1394           12.20s
#         70           0.1050           11.28s
#         80           0.0805           10.48s
#         90           0.0650            9.75s
#        100           0.0511            9.23s
#        200           0.0058            2.82s
# ^ learning rate: 0.500000, minimum test_loss = 6:0.558202552316
#       Iter       Train Loss   Remaining Time
#          1           1.2095           30.09s
#          2           1.1006           27.15s
#          3           1.0240           25.31s
#          4           0.9729           24.24s
#          5           0.9387           23.01s
#          6           0.8948           22.68s
#          7           0.8621           22.18s
#          8           0.8360           21.72s
#          9           0.8171           21.28s
#         10           0.7883           21.04s
#         20           0.6164           16.22s
#         30           0.4933           14.34s
#         40           0.4248           12.86s
#         50           0.3345           11.84s
#         60           0.2760           11.58s
#         70           0.2263           10.79s
#         80           0.1971           10.05s
#         90           0.1693            9.30s
#        100           0.1388            8.89s
#        200           0.0294            2.87s
# ^ learning rate: 0.300000, minimum test_loss = 18:0.542745177343
#       Iter       Train Loss   Remaining Time
#          1           1.2613           16.48s
#          2           1.1715           15.60s
#          3           1.1009           15.13s
#          4           1.0529           14.87s
#          5           1.0130           15.31s
#          6           0.9740           14.96s
#          7           0.9475           14.57s
#          8           0.9197           14.67s
#          9           0.8979           14.31s
#         10           0.8730           14.17s
#         20           0.7207           12.58s
#         30           0.6055           11.66s
#         40           0.5244           10.88s
#         50           0.4501           10.32s
#         60           0.3908           10.06s
#         70           0.3372            9.55s
#         80           0.3009            9.04s
#         90           0.2603            8.66s
#        100           0.2327            8.10s
#        200           0.0835            2.75s
# ^ learning rate: 0.200000, minimum test_loss = 36:0.530918156803
#       Iter       Train Loss   Remaining Time
#          1           1.3199           19.57s
#          2           1.2645           18.77s
#          3           1.2170           18.23s
#          4           1.1775           17.97s
#          5           1.1404           17.72s
#          6           1.1106           17.45s
#          7           1.0844           17.27s
#          8           1.0617           17.16s
#          9           1.0411           17.02s
#         10           1.0223           16.82s
#         20           0.8864           17.05s
#         30           0.7844           16.05s
#         40           0.7176           15.07s
#         50           0.6590           13.52s
#         60           0.6120           12.49s
#         70           0.5599           11.72s
#         80           0.5242           11.15s
#         90           0.4829           10.57s
#        100           0.4473            9.76s
#        200           0.2379            3.06s
# ^ learning rate: 0.100000, minimum test_loss = 51:0.526464613826

# %% [markdown]
# > На этих же данных обучите RandomForestClassifier с количеством деревьев, равным количеству итераций, на котором достигается наилучшее качество у градиентного бустинга из предыдущего пункта, c random_state=241 и остальными параметрами по умолчанию. Какое значение log-loss на тесте получается у этого случайного леса? (Не забывайте, что предсказания нужно получать с помощью функции predict_proba)

# %%
cls = RandomForestClassifier(n_estimators=36, n_jobs=-1, random_state=241)
cls.fit(X_train, y_train)
y_tree = cls.predict_proba(X_test)
log_loss(y_test, y_tree)
# Out:
# 0.54138128618040693
